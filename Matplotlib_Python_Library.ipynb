# %% [markdown]
# # Matplotlib Python Library

# %%
x=np.linspace(0,5,11)
y=x**2
z=x+y
p=z*x

# %%
import numpy as np
import matplotlib.pyplot as plt   #matplotlib is a grandfather library of data visualization
# %matplotlib inline

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot( 'r')

# %% [markdown]
# # Basic Commands of Matplotlib

# %%
plt.plot(x,y,z,p,'r')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Straight Line')
plt.show()

# %% [markdown]
# # Create Multiplots on Same Canvas

# %%
#Your Drawing sheet is a canvas on that canvas you have to draw the plots
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %% [markdown]
# # Matplotlib Object Oriented Method

# %%
fig=plt.figure()                             #It create a empty canvas
axes=fig.add_axes([0.1,0.1,0.8,0.8])         #Add set of axes to figure left,bottom,width,height(0-1)range
axes.plot(x,y,'b')                           #plot on that set of axes
axes.set_xlabel('This is X Axis')            # Here  set_ methodName strat
axes.set_ylabel('This is Y Axis')
axes.set_title('This is a Title')
# Out:
# Text(0.5,1,'This is a Title')

# %%
fig1=plt.figure()                         #create a canvas now we have to add two axeses
axes1=fig1.add_axes([0.1,0.1,0.8,0.8])    # axes1
axes2=fig1.add_axes([0.2,0.5,0.4,0.3])     # axes2

axes1.plot(x,y,x,y**2,x**2,y,'b')         # here 'b' for the blue Line
axes1.set_xlabel('X Axis')
axes1.set_ylabel('Y Axis')
axes1.set_title('Axese1 Titile')

axes2.plot(y,x,'r')
axes2.set_xlabel('X Label of axes2')
axes2.set_ylabel('Y Label  of axes2')
axes2.set_title('Title of axes2')
# Out:
# Text(0.5,1,'Title of axes2')

# %% [markdown]
# # Subplot()

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

for ax in axes:
    ax.plot(x,y,'g')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Title')
    
plt.tight_layout()

# %% [markdown]
# ## Figure size, aspect ratio and DPI

# %%
fig=plt.figure(figsize=(12,10),dpi=500)

# %%
fig, axes=plt.subplots(figsize=(6,4))

axes.plot(y,y**2,'r')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# # SaveFigure

# %%
pwd
# Out:
# 'C:\\Users\\Gops\\Desktop\\Practice\\03 Data Visualization\\Matplotlib'

# %%
fig.savefig("C:\\Users\\Gops\\Desktop\\Practice\\03 Data Visualization\\Matplotlib\\filenme.png")

# %%
fig.savefig("C:\\Users\\Gops\\Desktop\\Practice\\03 Data Visualization\\Matplotlib\\filenme1.jpg",dpi=300)

# %%
fig.savefig("gopal.png",dpi=200)

# %% [markdown]
# # Legend,Label and Titles

# %%
#Legend is the some introduction about the figure,legend chart position  can be change.
#legend may be inside or outside

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="x vs x**2")   # here label="labeled text"
ax.plot(x,x**3,label="x**3")      
ax.legend()                        #legend() without parameter
#ax.legend(loc=1)                   location at top right corner
#ax.legend(loc=2)                   location at top left corner(Default loc)
#ax.legend(loc=3)                   location at bottom left corner
#ax.legend(loc=4)                   location at bottom right corner

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.9) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11., 11., 12.,  7., 10., 10.,  5.,  9., 16.,  9.]),
#  array([  2. , 101.7, 201.4, 301.1, 400.8, 500.5, 600.2, 699.9, 799.6,
#         899.3, 999. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# # Advance Matplotlib

# %%
n = np.array([0,1,2,3,4,5])

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-b92aa4e04123> in <module>()
#       1 fig, axes = plt.subplots(1, 4, figsize=(12,3))
#       2
# ----> 3 axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
#       4 axes[0].set_title("scatter")
#       5
#
# NameError: name 'xx' is not defined

# %% [markdown]
# # Text Annotation

# %%
fig, ax = plt.subplots()
ax.plot(xx,xx**2,xx,xx*3)

ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-cc4c973a8c1c> in <module>()
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(xx,xx**2,xx,xx*3)
#       3
#       4 ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
#       5 ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");
#
# NameError: name 'xx' is not defined

# %%
fig, ax = plt.subplots(2, 3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()

# %% [markdown]
# # Colormap and contour figures

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %% [markdown]
# # pcolor

# %%
import matplotlib
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# # contour

# %%
fig, ax = plt.subplots()

cnt = ax.contour(Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max(), extent=[0, 1, 0, 1])

# %% [markdown]
# # 3D Figures

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %% [markdown]
# ## Surface plots

# %%
fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# ## Wireframe plot

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1, 1, 1, projection='3d')

p = ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

# %% [markdown]
# ## Countour Plots and  Projections

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=matplotlib.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);
